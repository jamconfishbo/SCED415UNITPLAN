# %% [markdown]
# # Before you begin the activity, watch this video:
#
# https://www.statisticshowto.com/probability-and-statistics/correlation-coefficient-formula/
#
# # Read this article:
# https://www.investopedia.com/terms/c/correlation.asp

# %% [markdown]
# # Do now:
# ### Estimate the corellation of the following graph by assigning them a number between -1 and 1

# %% [markdown]
# # Q1)
# ![download.png](attachment:download.png)

# %% [markdown]
# ### (double click here)
#
# ### Corelation Coefficient:

# %% [markdown]
# # Q2)
# ![1596563302378.webp](attachment:1596563302378.webp)

# %% [markdown]
# ### (double click here)
#
# ### Corelation Coefficient:

# %% [markdown]
# # Q3)
# ![Scatter_diagram_for_quality_characteristic_XXX.svg.png](attachment:Scatter_diagram_for_quality_characteristic_XXX.svg.png)

# %% [markdown]
# ### (double click here)
#
# ### Corelation Coefficient:

# %% [markdown]
# # Q4)
# ![matplotlib-scatter-exercise-1.png](attachment:matplotlib-scatter-exercise-1.png)

# %% [markdown]
# ### (double click here)
#
# ### Corelation Coefficient:

# %% [markdown]
# # Now Scroll Down until you see "Problems"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from sklearn.linear_model import LinearRegression
import os

# %%
infantmort = pd.read_csv(os.getcwd()+"/thedata/child-deaths-igme-data.csv")
usinfantmort =infantmort[infantmort["Entity"]  == "United States"]

gdp = pd.read_csv(os.getcwd()+"/thedata/us-gdp-per-capita-maddison-2020.csv")
usgdp = gdp[gdp["Entity"] == "United States"]

womenemployed = pd.read_csv(os.getcwd()+r"/thedata/female-labor-force-participation-OECD.csv") 
uswomenemployed = womenemployed[womenemployed["Entity"] == "United States"]

marriagerate = pd.read_csv(os.getcwd()+r"/thedata/marriage-rate-per-1000-inhabitants.csv") 
usmarriagerate = marriagerate[marriagerate["Entity"] == "United States"]

schoolrev = pd.read_csv(os.getcwd()+r"/thedata/revenues-for-public-schools-by-source-gdp-us.csv") 
usschoolrev = schoolrev[schoolrev["Entity"] == "United States"]


birthoutsidemarriage = pd.read_csv(os.getcwd()+r"/thedata/share-of-births-outside-marriage.csv") 
usbirthoutsidemarriage = birthoutsidemarriage[birthoutsidemarriage["Entity"] == "United States"]

fertrate = pd.read_csv(os.getcwd()+r"/thedata/fertilityrate-children-per-woman-UN.csv") 
usfertrate = fertrate[fertrate["Entity"] == "United States"]

# %%
usinfantmort
usgdp
uswomenemployed
usmarriagerate
usschoolrev
usbirthoutsidemarriage
usfertrate
bigdata = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(usinfantmort,usgdp, on = "Year", how = "outer"),uswomenemployed, on ="Year", how = "outer"),usmarriagerate, on = "Year", how = "outer"), usschoolrev, on = "Year", how = "outer"),usbirthoutsidemarriage, on = "Year", how = "outer"), usfertrate, on = "Year", how = "outer")

bigdata = bigdata[["Number of under-five deaths",
                  "GDP per capita",
                  "Female labor force participation rate (OWID based on OECD 2017 and others)",
                  "Crude marriage rate (per 1,000 inhabitants)",
                  "Local (US Bureau of the Census and NCES (2017))",
                  "State (US Bureau of the Census and NCES (2017))",
                  "Federal/Unassigned (US Bureau of the Census and NCES (2017))",
                  "Births outside of marriage (% of all births)",
                  "Fertility rate - Sex: all - Age: all - Variant: estimates"]]
# Out:
# /var/folders/fl/nrm2c0dd5h34_xnbsx7z_3240000gn/T/ipykernel_68169/3221857629.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Code_x', 'Entity_x'} in the result is deprecated and will raise a MergeError in a future version.
#   bigdata = pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(pd.merge(usinfantmort,usgdp, on = "Year", how = "outer"),uswomenemployed, on ="Year", how = "outer"),usmarriagerate, on = "Year", how = "outer"), usschoolrev, on = "Year", how = "outer"),usbirthoutsidemarriage, on = "Year", how = "outer"), usfertrate, on = "Year", how = "outer")
# /var/folders/fl/nrm2c0dd5h34_xnbsx7z_3240000gn/T/ipykernel_68169/3221857629.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Code_x', 'Entity_x'} in the result is deprecated and will raise a MergeError in a future version.
# ...

# %% [markdown]
# # Problems

# %% [markdown]
# ### Analyze the following correlation matrix below

# %% [markdown]
# # 1)
#
# ### Find three pairs of variables that have a strong positive correlation and list them here as ordered pairs of the form (x, y)

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 2)
#
# ### Write a paragraph for each of the three pairs explaining why they could have such a strong correlation. If you do not know why, then write about how this statistic makes you feel.

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 3)
#
# ### Find three pairs of variables that have a strong negative correlation and list them here as ordered pairs of the form (x, y)

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 4)
#
# ### Write a paragraph for each of the three pairs explaining why they could have such a strong negative correlation. If you do not know why, then write about how this statistic makes you feel.

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 5)
#
# ### Find three pairs of variables that have a weak correlation and list them here as ordered pairs of the form (x, y)

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 6)
#
# ### Write a paragraph for each of the three pairs explaining why they could have such a weak correlation. If you do not know why, then write about how this statistic makes you feel.

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %%
bigdata.corr()
# Out:
#                                                     Number of under-five deaths  \
# Number of under-five deaths                                            1.000000
# GDP per capita                                                        -0.883698
# Female labor force participation rate (OWID bas...                    -0.940761
# Crude marriage rate (per 1,000 inhabitants)                            0.437444
# Local (US Bureau of the Census and NCES (2017))                        0.076134
# State (US Bureau of the Census and NCES (2017))                       -0.961234
# Federal/Unassigned (US Bureau of the Census and...                    -0.623017
# Births outside of marriage (% of all births)                          -0.900988
# Fertility rate - Sex: all - Age: all - Variant:...                     0.858166
#
#                                                     GDP per capita  \
# Number of under-five deaths                              -0.883698
# ...

# %% [markdown]
# # 7)
#
# ## If you have not done so already, please write a paragraph for why you beleive there is such a strong negative correlation between the Female labor force participation rate, and the number of under-five deaths

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # 8)
#
# ### Recycle the code from Lesson 1 to find the linear regressions between three pairs of variables that have high correlation. Describe each graph with a few sentences and include information about where the model overestimates and underestimates the data.

# %%
###Your code goes here

# %% [markdown]
# # Exit Slip
#
# ### write two examples of pairs of variables that you want to know the correlation coefficients for and why you want to know them.

# %% [markdown]
# ### Answer: (double click here):
#
# ________________
# ________________

# %% [markdown]
# # To Submit:
# ## go to file --> Download as --> HTML (.html)
# ## submit the file to google classroom under the assignment "Intro to Data Analysis"
